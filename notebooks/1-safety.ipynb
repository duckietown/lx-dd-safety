# %% [markdown]
# # Safety
#
# Before you touch a drone, a soldering iron, or fly outdoors, you need to understand the risks
# involved and how to manage them. This learning experience walks you through the safety analysis
# you must complete before starting the *Introduction to Robotics with Drones* course.
#
# ## Intended learning outcomes
#
# After completing this learning experience, learners will be able to:
#
# 1. Analyze the safety considerations for operating a robot (drone) using the OSHA framework for
#    industrial robot and robot system safety.
# 2. Explain the FAA rules and regulations that govern operating an unmanned aircraft system (UAS),
#    including how to complete the TRUST certification.
# 3. Identify the institutional (Brown University) and personal (at-home) policies and precautions
#    that apply to flying a drone outside of the lab.
# 4. Set up a soldering station and a flight area that meet the safety requirements for this course.
#
# ## How this notebook works
#
# Each section below explains a safety topic, points you to the resource you need to read, and then
# gives you one or more questions to answer. Write your answers directly in the `answers.txt` file
# next to this notebook's assignment folder — every question below is numbered to match a heading in
# `answers.txt` (a template is generated by the code cell in each section, or you can copy the
# templates by hand). Photos are saved as `solder_station.jpg` and `fly_area.jpg` at the top level of
# your submission.
#
# **Submission:** you will submit exactly three files: `answers.txt`, `solder_station.jpg`, and
# `fly_area.jpg`.

# %%
# Run this cell once to create the answers.txt template you will fill in.
# It will not overwrite an existing answers.txt.
import os

template = """\
=====================================================
1. OSHA Safety Analysis
=====================================================

1.1 What tasks will the robot perform?


1.2 What are the startup, command, and programming procedures?


1.3 What are the relevant environmental conditions?


1.4 What are the location / installation requirements?


1.5 What potential human errors could occur?


1.6 What maintenance is required?


1.7 What robot and system malfunctions are possible?


1.8 What is the normal operation mode?


=====================================================
2. FAA Rules
=====================================================

2.1 What are the procedures for flying outdoors, beyond the CIT?


2.2 What is the nearest airport to campus (including heliports)?


2.3 What are the risks and potential injuries involved in flying a drone?


2.4 What are the FAA's accident reporting requirements?


=====================================================
3. Brown University Community Guidelines
=====================================================

3.1 What is the procedure for flying a drone on campus, outside of the designated lab space?


=====================================================
4. Flying at Home
=====================================================

4.1 How do the legal rules where you live differ from the FAA rules described above?


4.2 What are the risks of flying at home?


4.3 How will you plan a flight at home?


4.4 What precautions will you take to fly safely at home?

"""

if not os.path.exists("answers.txt"):
    with open("answers.txt", "w") as f:
        f.write(template)
    print("Created answers.txt — open it and fill in your answers.")
else:
    print("answers.txt already exists — leaving it untouched.")

# %% [markdown]
# ## 1. OSHA Safety Analysis *(50 points)*
#
# Robots — including drones — can injure the people operating and working around them if they are
# not used correctly. The Occupational Safety and Health Administration (OSHA) publishes a Technical
# Manual on Industrial Robots and Robot System Safety that lays out the standard framework for
# thinking about robot safety.
#
# **Read:** the OSHA Technical Manual, Section IV, Chapter 4 — *Industrial Robots and Robot System
# Safety* (search for it on osha.gov if the link your instructor gave you has moved).
#
# **Do:** applying the OSHA framework to the drone you will fly in this course, answer the following
# eight questions in section 1 of `answers.txt`:
#
# 1. What tasks will the robot perform?
# 2. What are the startup, command, and programming procedures?
# 3. What are the relevant environmental conditions?
# 4. What are the location / installation requirements?
# 5. What potential human errors could occur?
# 6. What maintenance is required?
# 7. What robot and system malfunctions are possible?
# 8. What is the normal operation mode?
#
# Write specific, concrete answers about *your* drone and *your* lab space — generic answers copied
# from the OSHA manual will not earn full credit.

# %% [markdown]
# ## 2. FAA Rules *(20 points)*
#
# Because a drone is an unmanned aircraft, flying one is regulated by the Federal Aviation
# Administration (FAA), not just by OSHA-style workplace safety rules.
#
# **Do:**
#
# 1. Review the FAA's [Unmanned Aircraft Systems](https://www.faa.gov/uas) website.
# 2. Complete **The Recreational UAS Safety Test (TRUST)** through any FAA-approved test
#    administrator. This is free and takes about 30 minutes. Keep the certificate — you may be asked
#    to show it before flying.
# 3. Answer the following four questions in section 2 of `answers.txt`:
#    1. What are the procedures for flying outdoors, beyond the CIT (or wherever your indoor lab
#       space is)?
#    2. What is the nearest airport to campus, including heliports?
#    3. What are the risks and potential injuries involved in flying a drone?
#    4. What are the FAA's requirements for reporting an accident?

# %% [markdown]
# ## 3. Brown University Community Guidelines *(5 points)*
#
# Even where the FAA permits flight, your institution may have its own policy on top of the FAA's
# rules.
#
# **Read:** Brown University's [UAS (drone) policy](https://ehs.brown.edu/occupational-health-safety/droneunmanned-aircraft-system-uas-policy).
#
# **Do:** answer the following question in section 3 of `answers.txt`:
#
# 1. What is the procedure for flying a drone on campus, outside of the designated lab space?

# %% [markdown]
# ## 4. Flying at Home *(5 points)*
#
# You may want to practice at home. The rules and risks there can be different from what you
# experience in the lab or on campus.
#
# **Do:** answer the following four questions in section 4 of `answers.txt`, based on where you will
# actually be flying:
#
# 1. How do the legal rules where you live differ from the FAA rules described above?
# 2. What are the risks of flying at home?
# 3. How will you plan a flight at home?
# 4. What precautions will you take to fly safely at home?

# %% [markdown]
# ## 5. Soldering Station Safety *(10 points)*
#
# Before soldering, set up your station so that it meets the following requirements, then photograph
# it and save the photo as `solder_station.jpg` in your submission folder.
#
# Your photo must clearly show:
#
# - A window or ventilation fan (to clear solder fumes)
# - A fire extinguisher nearby
# - A surge-protected power source
# - A non-flammable work surface
#
# Take the photo from far enough back, and with enough light, that a grader can verify all four items
# in a single image.

# %%
# Optional: preview your soldering station photo before submitting.
from pathlib import Path

path = Path("solder_station.jpg")
if path.exists():
    from IPython.display import Image, display
    display(Image(filename=str(path)))
else:
    print(f"{path} not found yet — take the photo and save it here before submitting.")

# %% [markdown]
# ## 6. Flight Area Safety *(10 points)*
#
# Set up the area where you will fly indoors, then photograph it and save the photo as
# `fly_area.jpg`.
#
# Your photo must clearly show:
#
# - A ceiling with no hazardous attachments (fans, exposed wiring, hanging fixtures, etc.)
# - A clear space at least 5 x 5 feet (1.5 x 1.5 meters)
# - Enough room around the flight area for spectators to stand a safe distance away

# %%
# Optional: preview your flight area photo before submitting.
from pathlib import Path

path = Path("fly_area.jpg")
if path.exists():
    from IPython.display import Image, display
    display(Image(filename=str(path)))
else:
    print(f"{path} not found yet — take the photo and save it here before submitting.")

# %% [markdown]
# ## Submission checklist
#
# Before submitting, confirm you have all three files in your submission folder:
#
# - [ ] `answers.txt` — all 17 questions across sections 1-4 answered
# - [ ] `solder_station.jpg` — shows ventilation, fire extinguisher, surge protector, non-flammable
#       surface
# - [ ] `fly_area.jpg` — shows a safe ceiling, a 5x5 ft (1.5x1.5 m) clear area, and room for
#       spectators
#
# Submit these three files through GitHub Classroom as instructed by your course staff.
